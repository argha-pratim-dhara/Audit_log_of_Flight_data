# %%
#Connect SFTP with Python
#Passing only the file name 
def myconnect(list1):
    ssh = paramiko.SSHClient()
    ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    ssh.connect('******',port=22,username='*****',password='******')
    sftp_client = ssh.open_sftp()
    path = '/home/ftpuser/biteam/Argha'
    sftp_client.chdir('/home/ftpuser/biteam/Argha')
    files = sftp_client.listdir()
    files.sort()
    final = pd.DataFrame()
    for i in files:
            df = pd.read_csv(sftp_client.open("/home/ftpuser/biteam/Argha/"+i))
            final = final.append(df,ignore_index=True)
    sftp_client.close()
    ssh.close()
    return final

# %%
#Connect SFTP with Python
#from the file name getting the audit log
import pandas as pd
import datetime as dt
import os
from pymongo import MongoClient
def py(list1):
    try:
        ssh = paramiko.SSHClient()
        ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
        ssh.connect('******',port=22,username='******',password='******')
        sftp_client = ssh.open_sftp()
        path = '/home/ftpuser/biteam/Argha'
        sftp_client.chdir('/home/ftpuser/biteam/Argha')
        audit_log = []
        count = 0
        final = pd.DataFrame()
        for obj in list1:
            try:
                i = obj['file_name']
                count += 1
                start_time= dt.datetime.now() 
                df = pd.read_csv(sftp_client.open("/home/ftpuser/biteam/Argha/"+i))
#                 final = final.append(df,ignore_index=True)
                size = round(((sftp_client.stat("/home/ftpuser/biteam/Argha/"+i).st_size)/1024),2)
                file_name = i
                number_of_records = len(df)
                end_time = dt.datetime.now()
                tim = round((end_time-start_time).total_seconds(),2)
#                 numberof_success_records = len(df)
#                 numberof_errors_records = 0
                status_of_processing = "Success"
                success_log = {"file_name":file_name,'number_of_records':number_of_records,"start_time":start_time,
                             "end_time":end_time,"number_of_fileProcessed":count,"time_taken_to_process_each_file":tim,
                             "size_of_file(KB)":size,"status_of_processing": status_of_processing}
                audit_log.append(success_log)
            except Exception as e:
                size = round(((sftp_client.stat("/home/ftpuser/biteam/Argha/"+i).st_size)/1024),2)
                file_name = i
                number_of_records = len(df)
                end_time = dt.datetime.now()
                tim = round((end_time-start_time).total_seconds(),2)
#                 numberof_errors_records = len(df)
#                 numberof_success_records = 0
                status_of_processing = str(e)
                error_log = {"file_name":file_name,'number_of_records':number_of_records,"start_time":start_time,
                             "end_time":end_time,"number_of_fileProcessed":count,"time_taken_to_process_each_file":tim,
                             "size_of_file(KB)":size,"status_of_processing": status_of_processing}
                audit_log.append(error_log)
        sftp_client.close()
        ssh.close()
        #connect to the mongoDB server
        client = MongoClient("mongodb://******:******1@mongo******ai:******/?authMechanism=DEFAULT&authSource=bi_testing&directConnection=true")
        mydb = client["bi_testing"]
        mycol = mydb["audit_log_argha"]
        x = mycol.insert_many(audit_log)
#         client.close()
        return audit_log
         
    except Exception as e:
        print(str(e))

# %%
py(list1)
# Out:
# [{'file_name': 'File1.csv',
#   'number_of_records': 49999,
#   'start_time': datetime.datetime(2022, 7, 5, 12, 14, 24, 525628),
#   'end_time': datetime.datetime(2022, 7, 5, 12, 14, 39, 695551),
#   'number_of_fileProcessed': 1,
#   'time_taken_to_process_each_file': 15.17,
#   'size_of_file(KB)': 4655.1,
#   'status_of_processing': 'Success'},
#  {'file_name': 'File10.csv',
#   'number_of_records': 61999,
#   'start_time': datetime.datetime(2022, 7, 5, 12, 14, 39, 695551),
#   'end_time': datetime.datetime(2022, 7, 5, 12, 14, 58, 829881),
#   'number_of_fileProcessed': 2,
#   'time_taken_to_process_each_file': 19.13,
#   'size_of_file(KB)': 5910.87,
#   'status_of_processing': 'Success'},
#  {'file_name': 'File2.csv',
#   'number_of_records': 89999,
#   'start_time': datetime.datetime(2022, 7, 5, 12, 14, 58, 829881),
#   'end_time': datetime.datetime(2022, 7, 5, 12, 15, 25, 681080),
#   'number_of_fileProcessed': 3,
#   'time_taken_to_process_each_file': 26.85,
# ...
